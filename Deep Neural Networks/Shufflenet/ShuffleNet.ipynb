# %%
import cv2
import os
import shutil
import torch,torchvision
import math
import pandas
import natsort
import torchvision.transforms as transforms
from torchvision import datasets
import torch.optim as optim
import numpy as np
from PIL import Image, ImageFilter
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/BinarySplit1"

# %%
def count_images_in_folder(folder_path):
    image_extensions = ['.jpg', '.jpeg', '.png']
    files = os.listdir(folder_path)
    num_images = sum(1 for file in files if os.path.isfile(os.path.join(folder_path, file)) and
                     any(file.lower().endswith(ext) for ext in image_extensions))
folder_path1 = 'BinarySplit/LessThan28'
folder_path2 = 'BinarySplit/GreaterThan29'

# %%
def count_images_in_folder(folder_path):
    image_extensions = [".jpg", ".jpeg", ".png"]
    files = os.listdir(folder_path)
    num_images = sum(
        1
        for file in files
        if os.path.isfile(os.path.join(folder_path, file))
        and any(file.lower().endswith(ext) for ext in image_extensions)
    )

# %%
def load_data(path, test_split, val_split, batch_size, input_size):
    modifyDict={'src':transforms.Compose([transforms.RandomHorizontalFlip(),
                                              transforms.Resize((224,224)),
                      transforms.RandomVerticalFlip(),
                      transforms.RandomRotation(15),
                      transforms.ToTensor(),
                      transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])}
    org_data = datasets.ImageFolder(root=path,transform =modifyDict['src'])
    testSubsetSize=int(len(org_data)*test_split)
    valDataSize=int(len(org_data)*val_split)
    trainSubsetSize=len(org_data)-valDataSize-testSubsetSize
    train_dataset,test_dataset,val_dataset = torch.utils.data.random_split(org_data,[trainSubsetSize,testSubsetSize,valDataSize])
    trainSetDataLoader = DataLoader(train_dataset,batch_size,shuffle=True)
    testSetDataLoader = DataLoader(test_dataset,batch_size,shuffle=False)
    valSetDataLoader = DataLoader(val_dataset,batch_size,shuffle=False)
    return trainSetDataLoader, testSetDataLoader, valSetDataLoader

# %%
train_loader, test_loader, val_loader = load_data(path, test_split=0.1, val_split= 0.1, batch_size=32, input_size=[224, 224])

# %%
model = torchvision.models.shufflenet_v2_x1_0(pretrained=False, num_classes=2)
optimizer = optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# /home/anmol/anaconda3/envs/comp6721/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/anmol/anaconda3/envs/comp6721/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       (branch1): Sequential()
#       (branch2): Sequential(
#         (0): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     (0): Conv2d(464, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (fc): Linear(in_features=1024, out_features=2, bias=True)
# )

# %%
numb_epochs = 100
training_loss = []
validation_loss = []
validation_accuracy = []
training_accuracy = []
for epoch in range(numb_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for images, labels in train_loader:
        labels = labels.to(device)
        images = images.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    training_loss.append(train_loss)
    training_accuracy.append(train_acc)
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        val_loss = 0.0
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        val_loss /= len(val_loader.dataset)
        val_acc = 100 * correct / total
        validation_loss.append(val_loss)
        validation_accuracy.append(val_acc)
        print(f'Epoch {epoch + 1}/{numb_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.2f}%')
# Out:
# Epoch 1/100, Train Loss: 0.6473, Train Accuracy: 62.48%, Validation Loss: 0.0359, Validation Accuracy: 69.15%
# Epoch 2/100, Train Loss: 0.5609, Train Accuracy: 70.71%, Validation Loss: 0.0347, Validation Accuracy: 72.36%
# Epoch 3/100, Train Loss: 0.5288, Train Accuracy: 73.16%, Validation Loss: 0.0320, Validation Accuracy: 74.66%
# Epoch 4/100, Train Loss: 0.5113, Train Accuracy: 74.94%, Validation Loss: 0.0527, Validation Accuracy: 63.55%
# Epoch 5/100, Train Loss: 0.4996, Train Accuracy: 74.97%, Validation Loss: 0.0328, Validation Accuracy: 73.51%
# Epoch 6/100, Train Loss: 0.4901, Train Accuracy: 75.60%, Validation Loss: 0.0306, Validation Accuracy: 75.56%
# Epoch 7/100, Train Loss: 0.4871, Train Accuracy: 75.83%, Validation Loss: 0.0292, Validation Accuracy: 77.92%
# Epoch 8/100, Train Loss: 0.4807, Train Accuracy: 76.20%, Validation Loss: 0.0281, Validation Accuracy: 77.82%
# Epoch 9/100, Train Loss: 0.4751, Train Accuracy: 76.78%, Validation Loss: 0.0281, Validation Accuracy: 77.87%
# Epoch 10/100, Train Loss: 0.4678, Train Accuracy: 76.88%, Validation Loss: 0.0322, Validation Accuracy: 72.16%
# Epoch 11/100, Train Loss: 0.4620, Train Accuracy: 77.32%, Validation Loss: 0.0275, Validation Accuracy: 78.72%
# Epoch 12/100, Train Loss: 0.4577, Train Accuracy: 77.62%, Validation Loss: 0.0273, Validation Accuracy: 78.47%
# Epoch 13/100, Train Loss: 0.4519, Train Accuracy: 78.29%, Validation Loss: 0.0358, Validation Accuracy: 73.81%
# Epoch 14/100, Train Loss: 0.4491, Train Accuracy: 77.97%, Validation Loss: 0.0262, Validation Accuracy: 79.82%
# Epoch 15/100, Train Loss: 0.4384, Train Accuracy: 78.64%, Validation Loss: 0.0259, Validation Accuracy: 80.57%
# Epoch 16/100, Train Loss: 0.4382, Train Accuracy: 78.92%, Validation Loss: 0.0256, Validation Accuracy: 80.47%
# Epoch 17/100, Train Loss: 0.4360, Train Accuracy: 78.60%, Validation Loss: 0.0262, Validation Accuracy: 80.57%
# Epoch 18/100, Train Loss: 0.4290, Train Accuracy: 79.38%, Validation Loss: 0.0263, Validation Accuracy: 79.77%
# Epoch 19/100, Train Loss: 0.4290, Train Accuracy: 79.53%, Validation Loss: 0.0253, Validation Accuracy: 81.32%
# Epoch 20/100, Train Loss: 0.4189, Train Accuracy: 80.01%, Validation Loss: 0.0254, Validation Accuracy: 80.97%
# Epoch 21/100, Train Loss: 0.4221, Train Accuracy: 79.74%, Validation Loss: 0.0248, Validation Accuracy: 81.57%
# Epoch 22/100, Train Loss: 0.4140, Train Accuracy: 80.32%, Validation Loss: 0.0253, Validation Accuracy: 79.87%
# Epoch 23/100, Train Loss: 0.4109, Train Accuracy: 79.91%, Validation Loss: 0.0259, Validation Accuracy: 79.92%
# Epoch 24/100, Train Loss: 0.4058, Train Accuracy: 80.35%, Validation Loss: 0.0248, Validation Accuracy: 82.22%
# Epoch 25/100, Train Loss: 0.4073, Train Accuracy: 80.27%, Validation Loss: 0.0240, Validation Accuracy: 82.27%
# Epoch 26/100, Train Loss: 0.3989, Train Accuracy: 80.85%, Validation Loss: 0.0248, Validation Accuracy: 81.62%
# Epoch 27/100, Train Loss: 0.3971, Train Accuracy: 81.17%, Validation Loss: 0.0248, Validation Accuracy: 81.67%
# Epoch 28/100, Train Loss: 0.3901, Train Accuracy: 81.17%, Validation Loss: 0.0240, Validation Accuracy: 82.22%
# Epoch 29/100, Train Loss: 0.3913, Train Accuracy: 81.24%, Validation Loss: 0.0244, Validation Accuracy: 81.22%
# Epoch 30/100, Train Loss: 0.3905, Train Accuracy: 81.33%, Validation Loss: 0.0253, Validation Accuracy: 80.77%
# Epoch 31/100, Train Loss: 0.3878, Train Accuracy: 81.09%, Validation Loss: 0.0246, Validation Accuracy: 80.97%
# Epoch 32/100, Train Loss: 0.3843, Train Accuracy: 81.62%, Validation Loss: 0.0237, Validation Accuracy: 81.97%
# Epoch 33/100, Train Loss: 0.3800, Train Accuracy: 81.95%, Validation Loss: 0.0239, Validation Accuracy: 82.32%
# Epoch 34/100, Train Loss: 0.3792, Train Accuracy: 81.91%, Validation Loss: 0.0237, Validation Accuracy: 82.32%
# Epoch 35/100, Train Loss: 0.3802, Train Accuracy: 81.86%, Validation Loss: 0.0237, Validation Accuracy: 82.17%
# Epoch 36/100, Train Loss: 0.3769, Train Accuracy: 82.11%, Validation Loss: 0.0236, Validation Accuracy: 82.12%
# Epoch 37/100, Train Loss: 0.3719, Train Accuracy: 82.19%, Validation Loss: 0.0238, Validation Accuracy: 82.92%
# Epoch 38/100, Train Loss: 0.3684, Train Accuracy: 82.60%, Validation Loss: 0.0233, Validation Accuracy: 82.72%
# Epoch 39/100, Train Loss: 0.3701, Train Accuracy: 82.23%, Validation Loss: 0.0239, Validation Accuracy: 82.42%
# Epoch 40/100, Train Loss: 0.3688, Train Accuracy: 82.19%, Validation Loss: 0.0234, Validation Accuracy: 82.67%
# Epoch 41/100, Train Loss: 0.3660, Train Accuracy: 82.54%, Validation Loss: 0.0237, Validation Accuracy: 82.67%
# Epoch 42/100, Train Loss: 0.3673, Train Accuracy: 82.46%, Validation Loss: 0.0235, Validation Accuracy: 81.67%
# Epoch 43/100, Train Loss: 0.3616, Train Accuracy: 83.02%, Validation Loss: 0.0229, Validation Accuracy: 83.07%
# Epoch 44/100, Train Loss: 0.3624, Train Accuracy: 83.30%, Validation Loss: 0.0231, Validation Accuracy: 82.57%
# Epoch 45/100, Train Loss: 0.3577, Train Accuracy: 83.12%, Validation Loss: 3324.4612, Validation Accuracy: 82.47%
# Epoch 46/100, Train Loss: 0.3616, Train Accuracy: 82.58%, Validation Loss: 0.0229, Validation Accuracy: 83.48%
# Epoch 47/100, Train Loss: 0.3552, Train Accuracy: 83.34%, Validation Loss: 0.0233, Validation Accuracy: 82.27%
# Epoch 48/100, Train Loss: 0.3594, Train Accuracy: 83.29%, Validation Loss: 0.0231, Validation Accuracy: 82.52%
# Epoch 49/100, Train Loss: 0.3512, Train Accuracy: 83.35%, Validation Loss: 0.0224, Validation Accuracy: 82.37%
# Epoch 50/100, Train Loss: 0.3509, Train Accuracy: 83.25%, Validation Loss: 0.0234, Validation Accuracy: 81.57%
# Epoch 51/100, Train Loss: 0.3495, Train Accuracy: 83.60%, Validation Loss: 0.0231, Validation Accuracy: 83.88%
# Epoch 52/100, Train Loss: 0.3498, Train Accuracy: 83.90%, Validation Loss: 0.0222, Validation Accuracy: 83.53%
# Epoch 53/100, Train Loss: 0.3458, Train Accuracy: 83.54%, Validation Loss: 16454.6196, Validation Accuracy: 82.87%
# Epoch 54/100, Train Loss: 0.3486, Train Accuracy: 83.41%, Validation Loss: 0.0226, Validation Accuracy: 83.98%
# Epoch 55/100, Train Loss: 0.3460, Train Accuracy: 83.61%, Validation Loss: 0.0236, Validation Accuracy: 82.87%
# Epoch 56/100, Train Loss: 0.3480, Train Accuracy: 83.31%, Validation Loss: 0.0226, Validation Accuracy: 83.07%
# Epoch 57/100, Train Loss: 0.3462, Train Accuracy: 83.56%, Validation Loss: 0.0233, Validation Accuracy: 83.38%
# Epoch 58/100, Train Loss: 0.3436, Train Accuracy: 84.00%, Validation Loss: 0.0229, Validation Accuracy: 82.32%
# Epoch 59/100, Train Loss: 0.3394, Train Accuracy: 83.80%, Validation Loss: 0.5924, Validation Accuracy: 82.17%
# Epoch 60/100, Train Loss: 0.3414, Train Accuracy: 84.00%, Validation Loss: 0.0241, Validation Accuracy: 81.72%
# Epoch 61/100, Train Loss: 0.3411, Train Accuracy: 84.11%, Validation Loss: 0.0239, Validation Accuracy: 81.92%
# Epoch 62/100, Train Loss: 0.3378, Train Accuracy: 84.36%, Validation Loss: 0.0234, Validation Accuracy: 83.43%
# Epoch 63/100, Train Loss: 0.3335, Train Accuracy: 84.42%, Validation Loss: 0.0236, Validation Accuracy: 84.13%
# Epoch 64/100, Train Loss: 0.3372, Train Accuracy: 83.91%, Validation Loss: 0.0234, Validation Accuracy: 82.82%
# Epoch 65/100, Train Loss: 0.3356, Train Accuracy: 84.37%, Validation Loss: 0.0229, Validation Accuracy: 82.92%
# Epoch 66/100, Train Loss: 0.3342, Train Accuracy: 84.30%, Validation Loss: 0.0233, Validation Accuracy: 82.77%
# Epoch 67/100, Train Loss: 0.3308, Train Accuracy: 84.73%, Validation Loss: 0.0225, Validation Accuracy: 83.68%
# Epoch 68/100, Train Loss: 0.3333, Train Accuracy: 84.31%, Validation Loss: 0.0230, Validation Accuracy: 83.12%
# Epoch 69/100, Train Loss: 0.3295, Train Accuracy: 84.56%, Validation Loss: 0.0227, Validation Accuracy: 84.13%
# Epoch 70/100, Train Loss: 0.3302, Train Accuracy: 84.57%, Validation Loss: 0.0235, Validation Accuracy: 82.42%
# Epoch 71/100, Train Loss: 0.3249, Train Accuracy: 84.72%, Validation Loss: 0.0229, Validation Accuracy: 83.43%
# Epoch 72/100, Train Loss: 0.3262, Train Accuracy: 84.67%, Validation Loss: 0.0228, Validation Accuracy: 83.27%
# Epoch 73/100, Train Loss: 0.3298, Train Accuracy: 84.56%, Validation Loss: 0.0223, Validation Accuracy: 83.63%
# Epoch 74/100, Train Loss: 0.3253, Train Accuracy: 84.90%, Validation Loss: 0.0239, Validation Accuracy: 82.57%
# Epoch 75/100, Train Loss: 0.3267, Train Accuracy: 84.73%, Validation Loss: 1453046.6649, Validation Accuracy: 83.32%
# Epoch 76/100, Train Loss: 0.3208, Train Accuracy: 85.01%, Validation Loss: 0.0227, Validation Accuracy: 84.93%
# Epoch 77/100, Train Loss: 0.3228, Train Accuracy: 84.80%, Validation Loss: 3206965737.2869, Validation Accuracy: 84.08%
# Epoch 78/100, Train Loss: 0.3240, Train Accuracy: 84.81%, Validation Loss: 25.1990, Validation Accuracy: 84.38%
# Epoch 79/100, Train Loss: 0.3196, Train Accuracy: 85.19%, Validation Loss: 11.9859, Validation Accuracy: 83.58%
# Epoch 80/100, Train Loss: 0.3186, Train Accuracy: 85.48%, Validation Loss: 1765.0211, Validation Accuracy: 82.87%
# Epoch 81/100, Train Loss: 0.3191, Train Accuracy: 85.42%, Validation Loss: 0.0224, Validation Accuracy: 83.93%
# Epoch 82/100, Train Loss: 0.3202, Train Accuracy: 85.05%, Validation Loss: 140594251088470.9375, Validation Accuracy: 81.37%
# Epoch 83/100, Train Loss: 0.3168, Train Accuracy: 85.34%, Validation Loss: 2021.3946, Validation Accuracy: 83.88%
# Epoch 84/100, Train Loss: 0.3176, Train Accuracy: 85.34%, Validation Loss: 0.0224, Validation Accuracy: 84.18%
# Epoch 85/100, Train Loss: 0.3147, Train Accuracy: 85.34%, Validation Loss: 0.0225, Validation Accuracy: 83.88%
# Epoch 86/100, Train Loss: 0.3132, Train Accuracy: 85.53%, Validation Loss: 0.0224, Validation Accuracy: 84.08%
# Epoch 87/100, Train Loss: 0.3155, Train Accuracy: 85.45%, Validation Loss: 10.2083, Validation Accuracy: 82.57%
# Epoch 88/100, Train Loss: 0.3144, Train Accuracy: 85.83%, Validation Loss: 0.0231, Validation Accuracy: 83.93%
# Epoch 89/100, Train Loss: 0.3103, Train Accuracy: 85.55%, Validation Loss: 37.9731, Validation Accuracy: 83.43%
# Epoch 90/100, Train Loss: 0.3101, Train Accuracy: 85.52%, Validation Loss: 38.0952, Validation Accuracy: 83.78%
# Epoch 91/100, Train Loss: 0.3123, Train Accuracy: 85.54%, Validation Loss: 2.0279, Validation Accuracy: 83.02%
# Epoch 92/100, Train Loss: 0.3095, Train Accuracy: 85.71%, Validation Loss: 0.0236, Validation Accuracy: 83.88%
# Epoch 93/100, Train Loss: 0.3084, Train Accuracy: 85.53%, Validation Loss: 71.9784, Validation Accuracy: 82.47%
# Epoch 94/100, Train Loss: 0.3040, Train Accuracy: 85.97%, Validation Loss: 3.5898, Validation Accuracy: 83.22%
# Epoch 95/100, Train Loss: 0.3004, Train Accuracy: 86.28%, Validation Loss: 0.4822, Validation Accuracy: 82.47%
# Epoch 96/100, Train Loss: 0.3041, Train Accuracy: 86.20%, Validation Loss: 35.2299, Validation Accuracy: 83.53%
# Epoch 97/100, Train Loss: 0.3043, Train Accuracy: 85.99%, Validation Loss: 0.0224, Validation Accuracy: 84.18%
# Epoch 98/100, Train Loss: 0.3008, Train Accuracy: 86.02%, Validation Loss: 330.1995, Validation Accuracy: 82.92%
# Epoch 99/100, Train Loss: 0.3006, Train Accuracy: 86.24%, Validation Loss: 5.9664, Validation Accuracy: 83.38%
# Epoch 100/100, Train Loss: 0.3021, Train Accuracy: 85.95%, Validation Loss: 36485055.4906, Validation Accuracy: 83.43%

# %%
plt.figure(figsize=(11,6))
plt.subplot(1,2,1)
plt.plot(training_loss,label='Training')
plt.plot(validation_loss, label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss')
plt.subplot(1,2,2)
plt.plot(training_accuracy, label='Training')
plt.plot(validation_accuracy, label='Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
model.eval()
with torch.no_grad():
    total = 0
    correct = 0
    y_exp = []
    y_pred = []
    for images, labels in test_loader:
        labels = labels.to(device)
        images = images.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        y_pred.extend(outputs.cpu().numpy())
        y_exp.extend(labels.cpu().numpy())
    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy}')
torch.save(model.state_dict(), "ShuffleNet.pth")
# Out:
# Test Accuracy: 83.07461191787681

# %%
y_pred = np.array(y_pred)
y_exp = np.array(y_exp)
y_pred = y_pred[:, 1]
y_exp = y_exp.reshape(y_pred.shape)
frp, tpr, thresholds = roc_curve(y_exp, y_pred)
roc_auc = auc(frp, tpr)
plt.figure()
plt.plot(frp, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc="lower right")
plt.title('Receiver operating characteristic')
plt.show()

# %%
y_pred = []
y_exp = []
for images, labels in test_loader:
        labels = labels.to(device)
        images = images.to(device)
        y_exp.extend(labels.cpu().numpy())
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        y_pred.extend(predicted.cpu().numpy())
conf_matrix = confusion_matrix(y_exp, y_pred)
class_names = ('LessThan28', 'GreaterThan29')
dataframe = pd.DataFrame(conf_matrix, index=class_names, columns=class_names)
plt.figure(figsize=(6, 6))
sns.heatmap(dataframe, annot=True, cbar=None,cmap="YlGnBu",fmt="d")
plt.title("Confusion Matrix"),
plt.tight_layout()
plt.xlabel("Predicted Class"),
plt.ylabel("True Class")
plt.show()
